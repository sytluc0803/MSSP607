# %% [markdown]
# <a href="https://colab.research.google.com/github/sytluc0803/MSSP607/blob/main/Modules/Week_3/Week_3_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a. When does the code in a function execute: when the function is defined or called?
#
# Answer:
# every function begins with the def and a function(). when I run the function(), the function is called.

# %% [markdown]
# b. How many global scopes are there in a Python program? How many local scopes?
#
#  Answer: there is only one global scope per module, but there can be an infinite number of local scopes

# %% [markdown]
# c. What happens to variables in a local scope when the function call returns?
#
# Answer: The local scope will be covered by a new one or no longer exist.

# %%
def collatz(number):
    if number % 2 == 0: #check for even or odd numbers
        print(number // 2, end=' ') # the print function adds the calculated number into the sequences
        return number // 2
    else:
        print(3 * number + 1, end=' ')
        return 3 * number + 1

print('Enter number:')
number = int(input())

print(number, end=' ')

while number != 1:
    number = collatz(number)
# Out:
# Enter number:
# 89
# 89 268 134 67 202 101 304 152 76 38 19 58 29 88 44 22 11 34 17 52 26 13 40 20 10 5 16 8 4 2 1
