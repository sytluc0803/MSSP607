# %% [markdown]
# <a href="https://colab.research.google.com/github/sytluc0803/MSSP607/blob/main/Modules/Week_4/Week_4_Ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import userdata
import os

github_token = userdata.get('Git_Key')
owner = 'sytluc0803'
repository = 'MSSP607'

clone_url = f'https://{github_token}@github.com/{owner}/{repository}.git'

# Clone the repository
import subprocess
subprocess.run(['git', 'clone', clone_url])

# Navigate into the cloned repository directory (optional, but often useful)
os.chdir(repository)
print(f"Changed directory to: {os.getcwd()}")
# Out:
# Changed directory to: /content/MSSP607

# %%
# %pushd "/content/MSSP607/Modules/Week_4"
# Out:
# /content/MSSP607/Modules/Week_4
# ['/content/MSSP607']

# %%
# !ls
# Out:
# parsed.csv  README.md  Week_4_Ex.ipynb

# %%
import numpy as np
import pandas as pd
import statistics

df = pd.read_csv('parsed.csv')
df.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...     status  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...  automatic
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  ...  automatic
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  ...  automatic
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  ...  automatic
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  ...  automatic
#
#             time                          title tsunami        type  \
# ...

# %%
## Q1
q1 = df[(df['magType'] == 'mb') & (df['parsed_place'] == 'Japan')& (df['type']=='earthquake')]
q1.head()

Q1 = statistics.quantiles(q1['mag'], n=100)
Q1

print(Q1[94])
# Out:
# 4.9

# %%
## Q2
Indo = df[(df['parsed_place'] == 'Indonesia') & (df['type']=='earthquake')]
Indo.head()

Q2 = Indo["tsunami"].mean()
print(Q2)
# Out:
# 0.23129251700680273

# %%
## Q3
Nev = df[(df['type'] == 'earthquake') & (df['parsed_place'] == 'Nevada')]
Nev.columns

Nev.describe()
# Out:
#              cdi        dmin       felt         gap         mag   mmi  \
# count  14.000000  647.000000  14.000000  647.000000  647.000000  1.00
# mean    2.421429    0.163155   2.500000  154.436615    0.437311  2.84
# std     0.514675    0.161793   4.783787   69.474945    0.653397   NaN
# min     2.000000    0.001000   1.000000   29.140000   -0.500000  2.84
# 25%     2.000000    0.053000   1.000000   97.295000   -0.100000  2.84
# 50%     2.200000    0.109000   1.000000  150.040000    0.300000  2.84
# 75%     3.000000    0.223000   1.000000  200.515000    0.800000  2.84
# max     3.300000    1.414000  19.000000  355.910000    2.900000  2.84
#
#               nst         rms         sig          time  tsunami     tz  \
# count  647.000000  647.000000  647.000000  6.470000e+02    647.0  647.0
# mean    12.704791    0.140627    9.146832  1.538318e+12      0.0 -480.0
# std     10.052695    0.056765   17.939055  5.954980e+08      0.0    0.0
# ...

# %%
## Q4
df['parsed_place'].unique()

places = [
    "Bolivia", "Chile", "Ecuador", "Peru", "Costa Rica", "Guatemala",
    "Mexico", "Japan", "Philippines", "Indonesia", "New Zealand",
    "Antarctic", "Canada", "Fiji", "Alaska", "Washington", "California",
    "Russia", "Taiwan", "Tonga", "Kermadec"
]

pattern = "|".join(places) ## prep the list for string mapping

df2 = df
df2["Ring of Fire"] = (
    df2["parsed_place"]
    .str.contains(pattern, case=False, na=False)
    .astype(int)
)
## overwriting the "New Mexico" variable in "Ring of Fire"
df2.loc[
    df2["parsed_place"].str.contains("New Mexico", case=False, na=False),
    "Ring of Fire"
] = 0

df2.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...           time  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...  1539475168010
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  ...  1539475129610
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  ...  1539475062610
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  ...  1539474978070
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  ...  1539474716050
#
#                            title  tsunami        type  \
# ...

# %%
## Q5
df3 = df2[df['type']== "earthquake"]
Q5 = df3['Ring of Fire'].value_counts()
print(Q5)
# Out:
# Ring of Fire
# 1    7004
# 0    2077
# Name: count, dtype: int64

# %%
## Q6
Q6 = pd.crosstab(df3["Ring of Fire"], df3["tsunami"])
print(Q6)

## In all the Ring of Fire region, 45 of the quakes have tsunami with them.
# Out:
# tsunami          0   1
# Ring of Fire
# 0             2061  16
# 1             6959  45
